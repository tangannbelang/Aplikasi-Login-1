# %% [markdown]
# <a href="https://colab.research.google.com/github/tangannbelang/Aplikasi-Login-1/blob/main/anomalydetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('fraud_detection.csv')

# %%
data.head(5)
# Out:
#    transaction_id     amount transaction_type
# 0               1  57.450712         purchase
# 1               2  47.926035         purchase
# 2               3  59.715328       withdrawal
# 3               4  72.845448       withdrawal
# 4               5  46.487699         transfer

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    300 non-null    int64
#  1   amount            300 non-null    float64
#  2   transaction_type  300 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#        transaction_id      amount
# count      300.000000  300.000000
# mean       150.500000   55.245506
# std         86.746758   30.001218
# min          1.000000    1.380990
# 25%         75.750000   40.016445
# 50%        150.500000   51.475467
# 75%        225.250000   61.305381
# max        300.000000  260.845895

# %%
data.isnull().sum()
# Out:
# transaction_id      0
# amount              0
# transaction_type    0
# dtype: int64

# %%
data['transaction_type'] = data['transaction_type'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    300 non-null    int64
#  1   amount            300 non-null    float64
#  2   transaction_type  300 non-null    category
# dtypes: category(1), float64(1), int64(1)
# memory usage: 5.2 KB

# %%
data.count()
# Out:
# transaction_id      300
# amount              300
# transaction_type    300
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['amount'], bins=30, kde=True)
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='transaction_types', data='transaction_types')
plt.title('Distribution of Transaction Types')
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3676546950.py in <cell line: 0>()
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.countplot(x='transaction_types', data='transaction_types')
#       3 plt.title('Distribution of Transaction Types')
#       4 plt.xlabel('Transaction Type')
#       5 plt.ylabel('Count')
#
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2629         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2630
# -> 2631     p = _CategoricalAggPlotter(
#    2632         data=data,
#    2633         variables=dict(x=x, y=y, hue=hue),
#
# ...
